# %% [markdown]
# # Importando Pandas e Requests

# %%
import pandas as pd
import requests as rq

# %%
r = rq.get('https://www.alura.com.br/api/cursos')
r.status_code
r.headers['content-type']
# Out:
# 'application/json'

# %% [markdown]
# # Criando *Dataframe*

# %%
base = r.json()
base
dados = pd.json_normalize(data = base, max_level= 0)
dados
# Out:
#       tempo_estimado                                 slug  \
# 0                  8  dot-net-6-identity-controle-usuario
# 1                 10               dotnet-criando-web-api
# 2                  8        dotnet-relacionando-entidades
# 3                  6                         empresa-agil
# 4                  6         acessibilidade-web-front-end
# ...              ...                                  ...
# 1415               8        wordpress-integracao-whatsapp
# 1416               8             worpress-sites-elementor
# 1417               8    xdebug-ferramenta-debug-profiling
# 1418              20        edicao-de-videos-para-youtube
# 1419              10  youtube-estrategias-sucesso-negocio
#
#                                                    nome
# 0     .NET 6 e Identity: implementando controle de u...
# 1                           .NET 6: criando uma web API
# 2                        .NET 6: relacionando entidades
# 3     A Empresa Ágil: introduzindo o Business Agilit...
# 4     Acessibilidade web parte 1: tornando seu front...
# ...                                                 ...
# 1415  Wordpress: integração whatsapp e internacional...
# 1416                     Wordpress: sites com Elementor
# 1417            XDebug: ferramenta de debug e profiling
# 1418        YouTube: da concepção de um canal ao upload
# 1419  YouTube: estratégias de sucesso para o seu neg...
#
# [1420 rows x 3 columns]

# %% [markdown]
# ## Detalhes dos Cursos

# %%
# r1 = rq.get('https://cursos.alura.com.br/api/curso-dot-net-6-identity-controle-usuario')
# r1.status_code
# r1.headers['content-type']
# base2 = r1.json()
# base2
# dados2 = pd.json_normalize(base2)
# dados2
slug = dados['slug'].unique()
slug
r2 = []
for i in slug:
   r2 += [pd.json_normalize(rq.get('https://cursos.alura.com.br/api/curso-{}'.format(i)).json(), max_level= 0)]
   
r3 = pd.concat(r2)
r3.reset_index(inplace= True)
r3
# Out:
#       index  showable    id                                 slug  \
# 0         0      True  2974  dot-net-6-identity-controle-usuario
# 1         0      True  2792               dotnet-criando-web-api
# 2         0      True  2876        dotnet-relacionando-entidades
# 3         0      True  1091                         empresa-agil
# 4         0      True   805         acessibilidade-web-front-end
# ...     ...       ...   ...                                  ...
# 1415      0      True  1592        wordpress-integracao-whatsapp
# 1416      0      True  1554             worpress-sites-elementor
# 1417      0      True  2571    xdebug-ferramenta-debug-profiling
# 1418      0      True   655        edicao-de-videos-para-youtube
# 1419      0      True  2493  youtube-estrategias-sucesso-negocio
#
#                                                    nome  \
# 0     .NET 6 e Identity: implementando controle de u...
# 1                           .NET 6: criando uma web API
# 2                        .NET 6: relacionando entidades
# 3     A Empresa Ágil: introduzindo o Business Agilit...
# 4     Acessibilidade web parte 1: tornando seu front...
# ...                                                 ...
# 1415  Wordpress: integração whatsapp e internacional...
# 1416                     Wordpress: sites com Elementor
# 1417            XDebug: ferramenta de debug e profiling
# 1418        YouTube: da concepção de um canal ao upload
# 1419  YouTube: estratégias de sucesso para o seu neg...
#
#                                         metadescription meta_title  \
# 0     Entenda como o Identity, integrado ao Entity, ...
# 1     Qualquer pessoa com conhecimento em C# que que...
# 2     Faça este curso e entenda como o Entity Framew...
# 3     Nesse curso você vai aprender os primeiros pas...
# 4     Curso prático para você deixar o front-end do ...
# ...                                                 ...        ...
# 1415  Cerca de 34% dos sites na internet foram desen...       None
# 1416  Wordpress é a plataforma de gerenciamento de c...       None
# 1417  Xdebug é uma ferramenta poderosa para debug (d...
# 1418                                               None       None
# 1419  Aprenda estratégias de marketing voltadas para...       None
#
#                                               categoria  \
# 0     {'nome': 'Programação', 'slug': 'programacao',...
# 1     {'nome': 'Programação', 'slug': 'programacao',...
# 2     {'nome': 'Programação', 'slug': 'programacao',...
# 3     {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
# 4     {'nome': 'Front-end', 'slug': 'front-end', 'or...
# ...                                                 ...
# 1415  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1416  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1417  {'nome': 'Programação', 'slug': 'programacao',...
# 1418  {'nome': 'UX & Design', 'slug': 'design-ux', '...
# 1419  {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
#
#                                            subcategoria  quantidade_aulas  \
# 0     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 1     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 6
# 2     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 3     {'slug': 'transformacao-agil', 'nome': 'Transf...                 6
# 4     {'slug': 'html-css', 'nome': 'HTML e CSS', 'me...                 5
# ...                                                 ...               ...
# 1415  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1416  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1417  {'slug': 'php', 'nome': 'PHP', 'metaTitle': No...                 5
# 1418  {'slug': 'edicao-video', 'nome': 'Edição de Ví...                 5
# 1419  {'slug': 'social-media', 'nome': 'Social Media...                 5
#
#       ...  carreiras  musicas  \
# 0     ...         []       []
# 1     ...         []       []
# 2     ...         []       []
# 3     ...         []       []
# 4     ...         []       []
# ...   ...        ...      ...
# 1415  ...         []       []
# 1416  ...         []       []
# 1417  ...         []       []
# 1418  ...         []       []
# 1419  ...         []       []
#
#                                             depoimentos  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [{'texto': 'Um curso rápido, enxuto. O profess...
# 4     [{'texto': 'Eu não imaginava que as coisas fun...
# ...                                                 ...
# 1415  [{'texto': 'Curso excelente com um projeto mui...
# 1416  [{'texto': 'Professor muito bom, aprendi muito...
# 1417                                                 []
# 1418  [{'texto': 'Achei muito bom o trabalho do prof...
# 1419                                                 []
#
#                                               formacoes  curso_substituto  \
# 0     [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...              None
# 1     [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...              None
# 2     [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...              None
# 3     [{'codigo': 'business-agility', 'cor': '#ff8c2...              None
# 4     [{'codigo': 'acessibilidade-web', 'cor': '#6bd...              None
# ...                                                 ...               ...
# 1415  [{'codigo': 'wordpress', 'cor': '#6bd1ff', 'ti...              None
# 1416  [{'codigo': 'wordpress', 'cor': '#6bd1ff', 'ti...              None
# 1417  [{'codigo': 'boas-praticas-php', 'cor': '#00c8...              None
# 1418  [{'codigo': 'editor-video', 'cor': '#dc6ebe', ...              None
# 1419  [{'codigo': 'social-media', 'cor': '#ff8c2a', ...              None
#
#                                           alunos_ativos  \
# 0     {'alunos': [{'username': 'felipeedc29', 'nome'...
# 1     {'alunos': [{'username': 'itamarbb1', 'nome': ...
# 2     {'alunos': [{'username': 'hufesouza', 'nome': ...
# 3     {'alunos': [{'username': 'carlos-henrique-s-j'...
# 4     {'alunos': [{'username': 'matheusw3314', 'nome...
# ...                                                 ...
# 1415  {'alunos': [{'username': 'ramon-ubt', 'nome': ...
# 1416  {'alunos': [{'username': 'loivos', 'nome': 'Di...
# 1417  {'alunos': [{'username': 'viniciusvferreira', ...
# 1418  {'alunos': [{'username': 'mariaclaudiapio', 'n...
# 1419  {'alunos': [{'username': 'simeylopes', 'nome':...
#
#                                               parceiros  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [{'imageUrl': 'https://cdn1.gnarususercontent....
# 4                                                    []
# ...                                                 ...
# 1415                                                 []
# 1416                                                 []
# 1417                                                 []
# 1418                                                 []
# 1419                                                 []
#
#                                           requerimentos highlightedExtraField  \
# 0                      [.NET 6: relacionando entidades]
# 1          [HTTP: entendendo a web por baixo dos panos]
# 2                         [.NET 6: criando uma web API]
# 3                                                    []
# 4     [HTML e CSS: ambientes de desenvolvimento, est...
# ...                                                 ...                   ...
# 1415                   [Wordpress: sites com Elementor]
# 1416                                                 []
# 1417              [PHP Exceptions: tratamento de erros]
# 1418                                                 []                  None
# 1419                                                 []
#
#                                          transcriptions
# 0     [{'sectionName': 'Conhecendo o Identity', 'tas...
# 1     [{'sectionName': 'Entendendo o conceito', 'tas...
# 2     [{'sectionName': 'Crescendo o projeto', 'taskN...
# 3     [{'sectionName': 'Business Agility', 'taskName...
# 4     [{'sectionName': 'HTML e os leitores de tela',...
# ...                                                 ...
# 1415  [{'sectionName': 'Cargos e permissões', 'taskN...
# 1416  [{'sectionName': 'Primeiros passos com o Wordp...
# 1417  [{'sectionName': 'Conhecendo o XDebug', 'taskN...
# 1418  [{'sectionName': 'Referências', 'taskName': 'I...
# 1419  [{'sectionName': 'O poder do YouTube', 'taskNa...
#
# [1420 rows x 34 columns]

# %% [markdown]
# # Visualizando as 15 primeiras linhas

# %%
r3_15 = r3.head(15)
r3_15
# Out:
#     index  showable    id                                               slug  \
# 0       0      True  2974                dot-net-6-identity-controle-usuario
# 1       0      True  2792                             dotnet-criando-web-api
# 2       0      True  2876                      dotnet-relacionando-entidades
# 3       0      True  1091                                       empresa-agil
# 4       0      True   805                       acessibilidade-web-front-end
# 5       0      True   823               acessibilidade-web-front-end-parte-2
# 6       0      True   735               acessibilidade-web-design-inclusivos
# 7       0      True  2115      big-query-manipulacao-programatico-linguagens
# 8       0      True  1224                            mysql-dba-administracao
# 9       0      True  2584  administracao-oracle-database-gerenciamento-banco
# 10      0      True  2585  administracao-oracle-database-seguranca-otimiz...
# 11      0      True   833                                         element-3d
# 12      0      True   896                           after-effects-personagem
# 13      0      True  2383  adobe-illustrator-mobile-pecas-redes-sociais-ipad
# 14      0      True  2528          adobe-illustrator-compondo-pecas-graficas
#
#                                                  nome  \
# 0   .NET 6 e Identity: implementando controle de u...
# 1                         .NET 6: criando uma web API
# 2                      .NET 6: relacionando entidades
# 3   A Empresa Ágil: introduzindo o Business Agilit...
# 4   Acessibilidade web parte 1: tornando seu front...
# 5   Acessibilidade web parte 2: componentes acessí...
# 6         Acessibilidade web: crie designs inclusivos
# 7   Acesso ao Big Query: manipulação programático ...
# 8   Administração do MySQL: segurança e otimização...
# 9   Administração do Oracle Database: criação e ge...
# 10  Administração do Oracle Database: segurança e ...
# 11  Adobe After Effects: animando a partir do Elem...
# 12  Adobe After Effects: construção do personagem ...
# 13  Adobe Illustrator Mobile: criando peças para r...
# 14         Adobe Illustrator: compondo peças gráficas
#
#                                       metadescription meta_title  \
# 0   Entenda como o Identity, integrado ao Entity, ...
# 1   Qualquer pessoa com conhecimento em C# que que...
# 2   Faça este curso e entenda como o Entity Framew...
# 3   Nesse curso você vai aprender os primeiros pas...
# 4   Curso prático para você deixar o front-end do ...
# 5   Depois de deixar o front-end do seu site mais ...       None
# 6   Curso com dicas para você deixar sua interface...       None
# 7   Aprenda como acessar o Big Query através de um...       None
# 8   O DBA (Database Administrator) tem um papel fu...       None
# 9   Oracle é um dos bancos de dados mais utilizado...
# 10  Oracle é um dos bancos de dados mais utilizado...
# 11  Adobe After Effects: animando a partir do Elem...
# 12  Aprenda a construir personagens animáveis usan...       None
# 13  Aprenda a utilizar o Adobe Illustrator Mobile ...       None
# 14  Aprenda a criar materiais de comunicação gráfi...       None
#
#                                             categoria  \
# 0   {'nome': 'Programação', 'slug': 'programacao',...
# 1   {'nome': 'Programação', 'slug': 'programacao',...
# 2   {'nome': 'Programação', 'slug': 'programacao',...
# 3   {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
# 4   {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 5   {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 6   {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 7   {'nome': 'Data Science', 'slug': 'data-science...
# 8   {'nome': 'Data Science', 'slug': 'data-science...
# 9   {'nome': 'Data Science', 'slug': 'data-science...
# 10  {'nome': 'Data Science', 'slug': 'data-science...
# 11  {'nome': 'UX & Design', 'slug': 'design-ux', '...
# 12  {'nome': 'UX & Design', 'slug': 'design-ux', '...
# 13  {'nome': 'UX & Design', 'slug': 'design-ux', '...
# 14  {'nome': 'UX & Design', 'slug': 'design-ux', '...
#
#                                          subcategoria  quantidade_aulas  ...  \
# 0   {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5  ...
# 1   {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 6  ...
# 2   {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5  ...
# 3   {'slug': 'transformacao-agil', 'nome': 'Transf...                 6  ...
# 4   {'slug': 'html-css', 'nome': 'HTML e CSS', 'me...                 5  ...
# 5   {'slug': 'html-css', 'nome': 'HTML e CSS', 'me...                 5  ...
# 6   {'slug': 'html-css', 'nome': 'HTML e CSS', 'me...                 5  ...
# 7   {'slug': 'nosql', 'nome': 'NoSQL', 'metaTitle'...                 6  ...
# 8   {'slug': 'sql', 'nome': 'SQL e Banco de Dados'...                 5  ...
# 9   {'slug': 'sql', 'nome': 'SQL e Banco de Dados'...                 5  ...
# 10  {'slug': 'sql', 'nome': 'SQL e Banco de Dados'...                 5  ...
# 11  {'slug': 'motion', 'nome': 'Motion Design', 'm...                 5  ...
# 12  {'slug': 'animacao', 'nome': 'Animação', 'meta...                 4  ...
# 13  {'slug': 'design-grafico', 'nome': 'Design Grá...                 4  ...
# 14  {'slug': 'design-grafico', 'nome': 'Design Grá...                 5  ...
#
#     carreiras  musicas                                        depoimentos  \
# 0          []       []                                                 []
# 1          []       []                                                 []
# 2          []       []                                                 []
# 3          []       []  [{'texto': 'Um curso rápido, enxuto. O profess...
# 4          []       []  [{'texto': 'Eu não imaginava que as coisas fun...
# 5          []       []  [{'texto': 'Tive alguns impedimentos ao longo ...
# 6          []       []  [{'texto': 'Nunca soube de nenhum curso aponta...
# 7          []       []                                                 []
# 8          []       []  [{'texto': 'Nas telas onde existem exercícios ...
# 9          []       []                                                 []
# 10         []       []                                                 []
# 11         []       []  [{'texto': 'Adorei o curso, o gaveta arrebenta...
# 12         []       []  [{'texto': 'adorei como ele fez as animações e...
# 13         []       []                                                 []
# 14         []       []                                                 []
#
#                                             formacoes  curso_substituto  \
# 0   [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...              None
# 1   [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...              None
# 2   [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...              None
# 3   [{'codigo': 'business-agility', 'cor': '#ff8c2...              None
# 4   [{'codigo': 'acessibilidade-web', 'cor': '#6bd...              None
# 5   [{'codigo': 'acessibilidade-web', 'cor': '#6bd...              None
# 6   [{'codigo': 'acessibilidade-web', 'cor': '#6bd...              None
# 7   [{'codigo': 'google-bigquery-datastudio', 'cor...              None
# 8   [{'codigo': 'oracle-mysql', 'cor': '#9cd33b', ...              None
# 9   [{'codigo': 'oracle-database-administracao-per...              None
# 10  [{'codigo': 'oracle-database-administracao-per...              None
# 11  [{'codigo': 'motion-design', 'cor': '#dc6ebe',...              None
# 12  [{'codigo': 'motion-design', 'cor': '#dc6ebe',...              None
# 13  [{'codigo': 'adobe-mobile', 'cor': '#dc6ebe', ...              None
# 14  [{'codigo': 'grafica-illustrator', 'cor': '#dc...              None
#
#                                         alunos_ativos  \
# 0   {'alunos': [{'username': 'felipeedc29', 'nome'...
# 1   {'alunos': [{'username': 'itamarbb1', 'nome': ...
# 2   {'alunos': [{'username': 'hufesouza', 'nome': ...
# 3   {'alunos': [{'username': 'carlos-henrique-s-j'...
# 4   {'alunos': [{'username': 'matheusw3314', 'nome...
# 5   {'alunos': [{'username': 'rodrigo-luz-e-silva'...
# 6   {'alunos': [{'username': 'natan-souza', 'nome'...
# 7                                                None
# 8   {'alunos': [{'username': 'luzoliveiralais', 'n...
# 9   {'alunos': [{'username': 'lucas-dpaula', 'nome...
# 10  {'alunos': [{'username': 'davi-fernandesd', 'n...
# 11  {'alunos': [{'username': 'douglasymide', 'nome...
# 12  {'alunos': [{'username': 'larissabritogarcia',...
# 13                                               None
# 14  {'alunos': [{'username': 'oademircastanha', 'n...
#
#                                             parceiros  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3   [{'imageUrl': 'https://cdn1.gnarususercontent....
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [{'imageUrl': 'https://cdn1.gnarususercontent....
# 12                                                 []
# 13                                                 []
# 14                                                 []
#
#                                         requerimentos highlightedExtraField  \
# 0                    [.NET 6: relacionando entidades]
# 1        [HTTP: entendendo a web por baixo dos panos]
# 2                       [.NET 6: criando uma web API]
# 3                                                  []
# 4   [HTML e CSS: ambientes de desenvolvimento, est...
# 5   [JavaScript e HTML: desenvolva um jogo e prati...
# 6                                                  []
# 7                    [BigQuery: manipulação de dados]
# 8        [Procedures SQL: executando código no MySQL]
# 9                 [Oracle PL/SQL: dominando packages]
# 10  [Administração do Oracle Database: criação e g...
# 11                                                 []
# 12                                                 []
# 13              [Adobe Illustrator: desenho vetorial]
# 14              [Adobe Illustrator: desenho vetorial]
#
#                                        transcriptions
# 0   [{'sectionName': 'Conhecendo o Identity', 'tas...
# 1   [{'sectionName': 'Entendendo o conceito', 'tas...
# 2   [{'sectionName': 'Crescendo o projeto', 'taskN...
# 3   [{'sectionName': 'Business Agility', 'taskName...
# 4   [{'sectionName': 'HTML e os leitores de tela',...
# 5   [{'sectionName': 'Melhorias iniciais', 'taskNa...
# 6   [{'sectionName': 'Acessibilidade e autismo', '...
# 7   [{'sectionName': 'Instalação e confguração do ...
# 8   [{'sectionName': 'O papel do DBA', 'taskName':...
# 9   [{'sectionName': 'Instalando o Oracle', 'taskN...
# 10  [{'sectionName': 'Estrutura do banco de dados'...
# 11  [{'sectionName': 'Primeiro contato com o Eleme...
# 12  [{'sectionName': 'Introdução', 'taskName': 'In...
# 13  [{'sectionName': 'Conhecendo o App', 'taskName...
# 14  [{'sectionName': 'Definição do estilo e logoti...
#
# [15 rows x 34 columns]

# %% [markdown]
# # Visualizando todas as colunas

# %%
pd.set_option("display.max_columns", 34)
r3
# Out:
#       index  showable    id                                 slug  \
# 0         0      True  2974  dot-net-6-identity-controle-usuario
# 1         0      True  2792               dotnet-criando-web-api
# 2         0      True  2876        dotnet-relacionando-entidades
# 3         0      True  1091                         empresa-agil
# 4         0      True   805         acessibilidade-web-front-end
# ...     ...       ...   ...                                  ...
# 1415      0      True  1592        wordpress-integracao-whatsapp
# 1416      0      True  1554             worpress-sites-elementor
# 1417      0      True  2571    xdebug-ferramenta-debug-profiling
# 1418      0      True   655        edicao-de-videos-para-youtube
# 1419      0      True  2493  youtube-estrategias-sucesso-negocio
#
#                                                    nome  \
# 0     .NET 6 e Identity: implementando controle de u...
# 1                           .NET 6: criando uma web API
# 2                        .NET 6: relacionando entidades
# 3     A Empresa Ágil: introduzindo o Business Agilit...
# 4     Acessibilidade web parte 1: tornando seu front...
# ...                                                 ...
# 1415  Wordpress: integração whatsapp e internacional...
# 1416                     Wordpress: sites com Elementor
# 1417            XDebug: ferramenta de debug e profiling
# 1418        YouTube: da concepção de um canal ao upload
# 1419  YouTube: estratégias de sucesso para o seu neg...
#
#                                         metadescription meta_title  \
# 0     Entenda como o Identity, integrado ao Entity, ...
# 1     Qualquer pessoa com conhecimento em C# que que...
# 2     Faça este curso e entenda como o Entity Framew...
# 3     Nesse curso você vai aprender os primeiros pas...
# 4     Curso prático para você deixar o front-end do ...
# ...                                                 ...        ...
# 1415  Cerca de 34% dos sites na internet foram desen...       None
# 1416  Wordpress é a plataforma de gerenciamento de c...       None
# 1417  Xdebug é uma ferramenta poderosa para debug (d...
# 1418                                               None       None
# 1419  Aprenda estratégias de marketing voltadas para...       None
#
#                                               categoria  \
# 0     {'nome': 'Programação', 'slug': 'programacao',...
# 1     {'nome': 'Programação', 'slug': 'programacao',...
# 2     {'nome': 'Programação', 'slug': 'programacao',...
# 3     {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
# 4     {'nome': 'Front-end', 'slug': 'front-end', 'or...
# ...                                                 ...
# 1415  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1416  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1417  {'nome': 'Programação', 'slug': 'programacao',...
# 1418  {'nome': 'UX & Design', 'slug': 'design-ux', '...
# 1419  {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
#
#                                            subcategoria  quantidade_aulas  \
# 0     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 1     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 6
# 2     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 3     {'slug': 'transformacao-agil', 'nome': 'Transf...                 6
# 4     {'slug': 'html-css', 'nome': 'HTML e CSS', 'me...                 5
# ...                                                 ...               ...
# 1415  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1416  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1417  {'slug': 'php', 'nome': 'PHP', 'metaTitle': No...                 5
# 1418  {'slug': 'edicao-video', 'nome': 'Edição de Ví...                 5
# 1419  {'slug': 'social-media', 'nome': 'Social Media...                 5
#
#       minutos_video  nota  nota_disponivel  quantidade_avaliacoes  \
# 0               131   9.3             True                    297
# 1               170   9.4             True                   1469
# 2               125   9.2             True                    571
# 3                80   9.3             True                  36772
# 4               154   9.2             True                  11748
# ...             ...   ...              ...                    ...
# 1415            141   9.3             True                   2401
# 1416            164   9.4             True                   4990
# 1417            123   9.3             True                    334
# 1418            156   8.8             True                   1426
# 1419            159   9.1             True                    654
#
#       quantidade_alunos  carga_horaria  quantidade_atividades data_criacao  \
# 0                   630              8                     45   2023-04-18
# 1                  3323             10                     55   2022-12-01
# 2                  1128              8                     44   2023-02-03
# 3                 42500              6                     31   2019-05-02
# 4                 22240              6                     50   2018-04-19
# ...                 ...            ...                    ...          ...
# 1415               4547              8                     51   2020-03-13
# 1416              12749              8                     55   2020-02-06
# 1417                669              8                     39   2022-06-06
# 1418               5936             20                     46   2017-08-11
# 1419               1385             10                     48   2022-04-14
#
#      data_atualizacao                                      video_1a_aula  \
# 0          2023-05-15  https://video.alura.com.br/alura/811381867-sd....
# 1          2023-05-04  https://video.alura.com.br/alura/769007907-sd....
# 2          2023-04-28  https://video.alura.com.br/alura/788410424-sd....
# 3          2023-02-09  https://video.alura.com.br/alura/754482117-sd....
# 4          2023-05-18  https://video.alura.com.br/alura/261911673-sd....
# ...               ...                                                ...
# 1415       2020-03-13  https://video.alura.com.br/alura/395300711-sd....
# 1416       2023-05-23  https://video.alura.com.br/alura/385087549-sd....
# 1417       2022-10-17  https://video.alura.com.br/alura/713066394-sd....
# 1418       2018-06-28  https://video.alura.com.br/alura/228287458-sd....
# 1419       2023-04-24  https://video.alura.com.br/alura/694494158-sd....
#
#                                            publico_alvo  \
# 0     Qualquer pessoa com conhecimento em C#, banco ...
# 1     Profissionais que já atuam no desenvolvimento ...
# 2     Qualquer pessoa com conhecimento em C# e na cr...
# 3     Estudantes que buscam qualificação profissiona...
# 4     Pessoas com conhecimentos básicos em HTML e CS...
# ...                                                 ...
# 1415  Pessoas interessadas em criar sites com o Word...
# 1416  Pessoas interessadas em criar sites com o Word...
# 1417  Desenvolvedores PHP interessados em depurar e ...
# 1418  Pessoas que desejam criar um canal no Youtube ...
# 1419  Profissionais que desejam aperfeiçoar técnicas...
#
#                                                chamadas  \
# 0     [Entenda conceitos de organização e separação ...
# 1     [Aprenda a receber requisições em sua API\r, E...
# 2     [Entenda como o Entity pode te ajudar a relaci...
# 3     [Aprenda como uma empresa aprende a ser Ágil\r...
# 4     [Melhore seu site para usuários de leitor de t...
# ...                                                 ...
# 1415  [Aprenda a fazer ajustes na versão desktop e m...
# 1416  [Saiba como instalar o Wordpress\r, Veja como ...
# 1417  [Use e aprimore o var_dump com Xdebug\r, Anali...
# 1418  [Aprenda a cortar os vídeos gravados para um c...
# 1419  [Identifique se o YouTube é ideal para o seu n...
#
#                                                  ementa  \
# 0     [{'capitulo': 'Conhecendo o Identity', 'secoes...
# 1     [{'capitulo': 'Entendendo o conceito', 'secoes...
# 2     [{'capitulo': 'Crescendo o projeto', 'secoes':...
# 3     [{'capitulo': 'Business Agility', 'secoes': ['...
# 4     [{'capitulo': 'HTML e os leitores de tela', 's...
# ...                                                 ...
# 1415  [{'capitulo': 'Cargos e permissões', 'secoes':...
# 1416  [{'capitulo': 'Primeiros passos com o Wordpres...
# 1417  [{'capitulo': 'Primeiros passos', 'secoes': ['...
# 1418  [{'capitulo': 'Referências', 'secoes': ['Busca...
# 1419  [{'capitulo': 'O poder do YouTube', 'secoes': ...
#
#                                             instrutores carreiras musicas  \
# 0     [{'twitter': 'https://twitter.com/DanielArtine...        []      []
# 1     [{'twitter': 'https://twitter.com/DanielArtine...        []      []
# 2     [{'twitter': 'https://twitter.com/DanielArtine...        []      []
# 3     [{'twitter': 'axmagno', 'linkedin': 'https://w...        []      []
# 4     [{'twitter': 'https://twitter.com/designernata...        []      []
# ...                                                 ...       ...     ...
# 1415  [{'twitter': '', 'linkedin': 'https://www.link...        []      []
# 1416  [{'twitter': '', 'linkedin': 'https://www.link...        []      []
# 1417  [{'twitter': 'https://twitter.com/cviniciussdi...        []      []
# 1418  [{'twitter': '', 'linkedin': 'https://www.link...        []      []
# 1419  [{'twitter': '', 'linkedin': '', 'username': '...        []      []
#
#                                             depoimentos  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [{'texto': 'Um curso rápido, enxuto. O profess...
# 4     [{'texto': 'Eu não imaginava que as coisas fun...
# ...                                                 ...
# 1415  [{'texto': 'Curso excelente com um projeto mui...
# 1416  [{'texto': 'Professor muito bom, aprendi muito...
# 1417                                                 []
# 1418  [{'texto': 'Achei muito bom o trabalho do prof...
# 1419                                                 []
#
#                                               formacoes curso_substituto  \
# 0     [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...             None
# 1     [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...             None
# 2     [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...             None
# 3     [{'codigo': 'business-agility', 'cor': '#ff8c2...             None
# 4     [{'codigo': 'acessibilidade-web', 'cor': '#6bd...             None
# ...                                                 ...              ...
# 1415  [{'codigo': 'wordpress', 'cor': '#6bd1ff', 'ti...             None
# 1416  [{'codigo': 'wordpress', 'cor': '#6bd1ff', 'ti...             None
# 1417  [{'codigo': 'boas-praticas-php', 'cor': '#00c8...             None
# 1418  [{'codigo': 'editor-video', 'cor': '#dc6ebe', ...             None
# 1419  [{'codigo': 'social-media', 'cor': '#ff8c2a', ...             None
#
#                                           alunos_ativos  \
# 0     {'alunos': [{'username': 'felipeedc29', 'nome'...
# 1     {'alunos': [{'username': 'itamarbb1', 'nome': ...
# 2     {'alunos': [{'username': 'hufesouza', 'nome': ...
# 3     {'alunos': [{'username': 'carlos-henrique-s-j'...
# 4     {'alunos': [{'username': 'matheusw3314', 'nome...
# ...                                                 ...
# 1415  {'alunos': [{'username': 'ramon-ubt', 'nome': ...
# 1416  {'alunos': [{'username': 'loivos', 'nome': 'Di...
# 1417  {'alunos': [{'username': 'viniciusvferreira', ...
# 1418  {'alunos': [{'username': 'mariaclaudiapio', 'n...
# 1419  {'alunos': [{'username': 'simeylopes', 'nome':...
#
#                                               parceiros  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [{'imageUrl': 'https://cdn1.gnarususercontent....
# 4                                                    []
# ...                                                 ...
# 1415                                                 []
# 1416                                                 []
# 1417                                                 []
# 1418                                                 []
# 1419                                                 []
#
#                                           requerimentos highlightedExtraField  \
# 0                      [.NET 6: relacionando entidades]
# 1          [HTTP: entendendo a web por baixo dos panos]
# 2                         [.NET 6: criando uma web API]
# 3                                                    []
# 4     [HTML e CSS: ambientes de desenvolvimento, est...
# ...                                                 ...                   ...
# 1415                   [Wordpress: sites com Elementor]
# 1416                                                 []
# 1417              [PHP Exceptions: tratamento de erros]
# 1418                                                 []                  None
# 1419                                                 []
#
#                                          transcriptions
# 0     [{'sectionName': 'Conhecendo o Identity', 'tas...
# 1     [{'sectionName': 'Entendendo o conceito', 'tas...
# 2     [{'sectionName': 'Crescendo o projeto', 'taskN...
# 3     [{'sectionName': 'Business Agility', 'taskName...
# 4     [{'sectionName': 'HTML e os leitores de tela',...
# ...                                                 ...
# 1415  [{'sectionName': 'Cargos e permissões', 'taskN...
# 1416  [{'sectionName': 'Primeiros passos com o Wordp...
# 1417  [{'sectionName': 'Conhecendo o XDebug', 'taskN...
# 1418  [{'sectionName': 'Referências', 'taskName': 'I...
# 1419  [{'sectionName': 'O poder do YouTube', 'taskNa...
#
# [1420 rows x 34 columns]

# %% [markdown]
# # Removendo colunas

# %%
pd.reset_option("display.max_columns")
r3.drop(labels= ['index', 'ementa', 'chamadas', 'publico_alvo', 'video_1a_aula', 'instrutores', 'musicas', 'depoimentos', 'transcriptions', 'highlightedExtraField', 'curso_substituto', 'meta_title', 'video_1a_aula', 'parceiros', 'formacoes'], axis= 1, inplace= True)
r3
# Out:
#       index  showable    id                                 slug  \
# 0         0      True  2974  dot-net-6-identity-controle-usuario
# 1         0      True  2792               dotnet-criando-web-api
# 2         0      True  2876        dotnet-relacionando-entidades
# 3         0      True  1091                         empresa-agil
# 4         0      True   805         acessibilidade-web-front-end
# ...     ...       ...   ...                                  ...
# 1415      0      True  1592        wordpress-integracao-whatsapp
# 1416      0      True  1554             worpress-sites-elementor
# 1417      0      True  2571    xdebug-ferramenta-debug-profiling
# 1418      0      True   655        edicao-de-videos-para-youtube
# 1419      0      True  2493  youtube-estrategias-sucesso-negocio
#
#                                                    nome  \
# 0     .NET 6 e Identity: implementando controle de u...
# 1                           .NET 6: criando uma web API
# 2                        .NET 6: relacionando entidades
# 3     A Empresa Ágil: introduzindo o Business Agilit...
# 4     Acessibilidade web parte 1: tornando seu front...
# ...                                                 ...
# 1415  Wordpress: integração whatsapp e internacional...
# 1416                     Wordpress: sites com Elementor
# 1417            XDebug: ferramenta de debug e profiling
# 1418        YouTube: da concepção de um canal ao upload
# 1419  YouTube: estratégias de sucesso para o seu neg...
#
#                                         metadescription  \
# 0     Entenda como o Identity, integrado ao Entity, ...
# 1     Qualquer pessoa com conhecimento em C# que que...
# 2     Faça este curso e entenda como o Entity Framew...
# 3     Nesse curso você vai aprender os primeiros pas...
# 4     Curso prático para você deixar o front-end do ...
# ...                                                 ...
# 1415  Cerca de 34% dos sites na internet foram desen...
# 1416  Wordpress é a plataforma de gerenciamento de c...
# 1417  Xdebug é uma ferramenta poderosa para debug (d...
# 1418                                               None
# 1419  Aprenda estratégias de marketing voltadas para...
#
#                                               categoria  \
# 0     {'nome': 'Programação', 'slug': 'programacao',...
# 1     {'nome': 'Programação', 'slug': 'programacao',...
# 2     {'nome': 'Programação', 'slug': 'programacao',...
# 3     {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
# 4     {'nome': 'Front-end', 'slug': 'front-end', 'or...
# ...                                                 ...
# 1415  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1416  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1417  {'nome': 'Programação', 'slug': 'programacao',...
# 1418  {'nome': 'UX & Design', 'slug': 'design-ux', '...
# 1419  {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
#
#                                            subcategoria  quantidade_aulas  \
# 0     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 1     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 6
# 2     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 3     {'slug': 'transformacao-agil', 'nome': 'Transf...                 6
# 4     {'slug': 'html-css', 'nome': 'HTML e CSS', 'me...                 5
# ...                                                 ...               ...
# 1415  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1416  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1417  {'slug': 'php', 'nome': 'PHP', 'metaTitle': No...                 5
# 1418  {'slug': 'edicao-video', 'nome': 'Edição de Ví...                 5
# 1419  {'slug': 'social-media', 'nome': 'Social Media...                 5
#
#       minutos_video  ...  nota_disponivel  quantidade_avaliacoes  \
# 0               131  ...             True                    297
# 1               170  ...             True                   1469
# 2               125  ...             True                    571
# 3                80  ...             True                  36772
# 4               154  ...             True                  11748
# ...             ...  ...              ...                    ...
# 1415            141  ...             True                   2401
# 1416            164  ...             True                   4990
# 1417            123  ...             True                    334
# 1418            156  ...             True                   1426
# 1419            159  ...             True                    654
#
#       quantidade_alunos  carga_horaria  quantidade_atividades  data_criacao  \
# 0                   630              8                     45    2023-04-18
# 1                  3323             10                     55    2022-12-01
# 2                  1128              8                     44    2023-02-03
# 3                 42500              6                     31    2019-05-02
# 4                 22240              6                     50    2018-04-19
# ...                 ...            ...                    ...           ...
# 1415               4547              8                     51    2020-03-13
# 1416              12749              8                     55    2020-02-06
# 1417                669              8                     39    2022-06-06
# 1418               5936             20                     46    2017-08-11
# 1419               1385             10                     48    2022-04-14
#
#      data_atualizacao carreiras  \
# 0          2023-05-15        []
# 1          2023-05-04        []
# 2          2023-04-28        []
# 3          2023-02-09        []
# 4          2023-05-18        []
# ...               ...       ...
# 1415       2020-03-13        []
# 1416       2023-05-23        []
# 1417       2022-10-17        []
# 1418       2018-06-28        []
# 1419       2023-04-24        []
#
#                                           alunos_ativos  \
# 0     {'alunos': [{'username': 'felipeedc29', 'nome'...
# 1     {'alunos': [{'username': 'itamarbb1', 'nome': ...
# 2     {'alunos': [{'username': 'hufesouza', 'nome': ...
# 3     {'alunos': [{'username': 'carlos-henrique-s-j'...
# 4     {'alunos': [{'username': 'matheusw3314', 'nome...
# ...                                                 ...
# 1415  {'alunos': [{'username': 'ramon-ubt', 'nome': ...
# 1416  {'alunos': [{'username': 'loivos', 'nome': 'Di...
# 1417  {'alunos': [{'username': 'viniciusvferreira', ...
# 1418  {'alunos': [{'username': 'mariaclaudiapio', 'n...
# 1419  {'alunos': [{'username': 'simeylopes', 'nome':...
#
#                                           requerimentos
# 0                      [.NET 6: relacionando entidades]
# 1          [HTTP: entendendo a web por baixo dos panos]
# 2                         [.NET 6: criando uma web API]
# 3                                                    []
# 4     [HTML e CSS: ambientes de desenvolvimento, est...
# ...                                                 ...
# 1415                   [Wordpress: sites com Elementor]
# 1416                                                 []
# 1417              [PHP Exceptions: tratamento de erros]
# 1418                                                 []
# 1419                                                 []
#
# [1420 rows x 21 columns]

# %% [markdown]
# # Capturando o total de alunos

# %%
r3['alunos_ativos_total'] = pd.json_normalize(r3['alunos_ativos'])['total']
r3
# Out:
#       index  showable    id                                 slug  \
# 0         0      True  2974  dot-net-6-identity-controle-usuario
# 1         0      True  2792               dotnet-criando-web-api
# 2         0      True  2876        dotnet-relacionando-entidades
# 3         0      True  1091                         empresa-agil
# 4         0      True   805         acessibilidade-web-front-end
# ...     ...       ...   ...                                  ...
# 1415      0      True  1592        wordpress-integracao-whatsapp
# 1416      0      True  1554             worpress-sites-elementor
# 1417      0      True  2571    xdebug-ferramenta-debug-profiling
# 1418      0      True   655        edicao-de-videos-para-youtube
# 1419      0      True  2493  youtube-estrategias-sucesso-negocio
#
#                                                    nome  \
# 0     .NET 6 e Identity: implementando controle de u...
# 1                           .NET 6: criando uma web API
# 2                        .NET 6: relacionando entidades
# 3     A Empresa Ágil: introduzindo o Business Agilit...
# 4     Acessibilidade web parte 1: tornando seu front...
# ...                                                 ...
# 1415  Wordpress: integração whatsapp e internacional...
# 1416                     Wordpress: sites com Elementor
# 1417            XDebug: ferramenta de debug e profiling
# 1418        YouTube: da concepção de um canal ao upload
# 1419  YouTube: estratégias de sucesso para o seu neg...
#
#                                         metadescription  \
# 0     Entenda como o Identity, integrado ao Entity, ...
# 1     Qualquer pessoa com conhecimento em C# que que...
# 2     Faça este curso e entenda como o Entity Framew...
# 3     Nesse curso você vai aprender os primeiros pas...
# 4     Curso prático para você deixar o front-end do ...
# ...                                                 ...
# 1415  Cerca de 34% dos sites na internet foram desen...
# 1416  Wordpress é a plataforma de gerenciamento de c...
# 1417  Xdebug é uma ferramenta poderosa para debug (d...
# 1418                                               None
# 1419  Aprenda estratégias de marketing voltadas para...
#
#                                               categoria  \
# 0     {'nome': 'Programação', 'slug': 'programacao',...
# 1     {'nome': 'Programação', 'slug': 'programacao',...
# 2     {'nome': 'Programação', 'slug': 'programacao',...
# 3     {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
# 4     {'nome': 'Front-end', 'slug': 'front-end', 'or...
# ...                                                 ...
# 1415  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1416  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1417  {'nome': 'Programação', 'slug': 'programacao',...
# 1418  {'nome': 'UX & Design', 'slug': 'design-ux', '...
# 1419  {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
#
#                                            subcategoria  quantidade_aulas  \
# 0     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 1     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 6
# 2     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 3     {'slug': 'transformacao-agil', 'nome': 'Transf...                 6
# 4     {'slug': 'html-css', 'nome': 'HTML e CSS', 'me...                 5
# ...                                                 ...               ...
# 1415  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1416  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1417  {'slug': 'php', 'nome': 'PHP', 'metaTitle': No...                 5
# 1418  {'slug': 'edicao-video', 'nome': 'Edição de Ví...                 5
# 1419  {'slug': 'social-media', 'nome': 'Social Media...                 5
#
#       minutos_video  ...  quantidade_avaliacoes  quantidade_alunos  \
# 0               131  ...                    297                630
# 1               170  ...                   1469               3323
# 2               125  ...                    571               1128
# 3                80  ...                  36772              42500
# 4               154  ...                  11748              22240
# ...             ...  ...                    ...                ...
# 1415            141  ...                   2401               4547
# 1416            164  ...                   4990              12749
# 1417            123  ...                    334                669
# 1418            156  ...                   1426               5936
# 1419            159  ...                    654               1385
#
#       carga_horaria  quantidade_atividades  data_criacao  data_atualizacao  \
# 0                 8                     45    2023-04-18        2023-05-15
# 1                10                     55    2022-12-01        2023-05-04
# 2                 8                     44    2023-02-03        2023-04-28
# 3                 6                     31    2019-05-02        2023-02-09
# 4                 6                     50    2018-04-19        2023-05-18
# ...             ...                    ...           ...               ...
# 1415              8                     51    2020-03-13        2020-03-13
# 1416              8                     55    2020-02-06        2023-05-23
# 1417              8                     39    2022-06-06        2022-10-17
# 1418             20                     46    2017-08-11        2018-06-28
# 1419             10                     48    2022-04-14        2023-04-24
#
#      carreiras                                      alunos_ativos  \
# 0           []  {'alunos': [{'username': 'felipeedc29', 'nome'...
# 1           []  {'alunos': [{'username': 'itamarbb1', 'nome': ...
# 2           []  {'alunos': [{'username': 'hufesouza', 'nome': ...
# 3           []  {'alunos': [{'username': 'carlos-henrique-s-j'...
# 4           []  {'alunos': [{'username': 'matheusw3314', 'nome...
# ...        ...                                                ...
# 1415        []  {'alunos': [{'username': 'ramon-ubt', 'nome': ...
# 1416        []  {'alunos': [{'username': 'loivos', 'nome': 'Di...
# 1417        []  {'alunos': [{'username': 'viniciusvferreira', ...
# 1418        []  {'alunos': [{'username': 'mariaclaudiapio', 'n...
# 1419        []  {'alunos': [{'username': 'simeylopes', 'nome':...
#
#                                           requerimentos alunos_ativos_total
# 0                      [.NET 6: relacionando entidades]               413.0
# 1          [HTTP: entendendo a web por baixo dos panos]              1026.0
# 2                         [.NET 6: criando uma web API]               393.0
# 3                                                    []              1821.0
# 4     [HTML e CSS: ambientes de desenvolvimento, est...              1125.0
# ...                                                 ...                 ...
# 1415                   [Wordpress: sites com Elementor]               236.0
# 1416                                                 []               879.0
# 1417              [PHP Exceptions: tratamento de erros]                66.0
# 1418                                                 []               160.0
# 1419                                                 []               135.0
#
# [1420 rows x 22 columns]

# %% [markdown]
# # Nome da Categoria e Subcategoria

# %%
r3['categoria_nome'] = pd.json_normalize(r3['categoria'])['nome']
r3['subcategoria_nome'] = pd.json_normalize(r3['subcategoria'])['nome']
r3
# Out:
#                                                  alunos   total
# 0     [{'username': 'felipeedc29', 'nome': 'Felipe E...   413.0
# 1     [{'username': 'itamarbb1', 'nome': 'Itamar Ber...  1026.0
# 2     [{'username': 'hufesouza', 'nome': 'Hugo Ferre...   393.0
# 3     [{'username': 'carlos-henrique-s-j', 'nome': '...  1821.0
# 4     [{'username': 'matheusw3314', 'nome': 'Matheus...  1125.0
# ...                                                 ...     ...
# 1415  [{'username': 'ramon-ubt', 'nome': 'Ramon Oliv...   236.0
# 1416  [{'username': 'loivos', 'nome': 'Diogo Fontinh...   879.0
# 1417  [{'username': 'viniciusvferreira', 'nome': 'Vi...    66.0
# 1418  [{'username': 'mariaclaudiapio', 'nome': 'Mari...   160.0
# 1419  [{'username': 'simeylopes', 'nome': 'Simey Lop...   135.0
#
# [1420 rows x 2 columns]

# %% [markdown]
# # Classificação pela quantidade de alunos

# %%
classes = ['Moderadamente Popular', 'Popular', 'Muito Popular']
bins = [r3['quantidade_alunos'].min(),r3['quantidade_alunos'].quantile(0.33), r3['quantidade_alunos'].quantile(0.66), r3['quantidade_alunos'].max()]
bins
r3['popularidade'] = pd.cut(x = r3['quantidade_alunos'], bins = bins, labels= classes, include_lowest= True)
r3
# Out:
#       index  showable    id                                 slug  \
# 0         0      True  2974  dot-net-6-identity-controle-usuario
# 1         0      True  2792               dotnet-criando-web-api
# 2         0      True  2876        dotnet-relacionando-entidades
# 3         0      True  1091                         empresa-agil
# 4         0      True   805         acessibilidade-web-front-end
# ...     ...       ...   ...                                  ...
# 1415      0      True  1592        wordpress-integracao-whatsapp
# 1416      0      True  1554             worpress-sites-elementor
# 1417      0      True  2571    xdebug-ferramenta-debug-profiling
# 1418      0      True   655        edicao-de-videos-para-youtube
# 1419      0      True  2493  youtube-estrategias-sucesso-negocio
#
#                                                    nome  \
# 0     .NET 6 e Identity: implementando controle de u...
# 1                           .NET 6: criando uma web API
# 2                        .NET 6: relacionando entidades
# 3     A Empresa Ágil: introduzindo o Business Agilit...
# 4     Acessibilidade web parte 1: tornando seu front...
# ...                                                 ...
# 1415  Wordpress: integração whatsapp e internacional...
# 1416                     Wordpress: sites com Elementor
# 1417            XDebug: ferramenta de debug e profiling
# 1418        YouTube: da concepção de um canal ao upload
# 1419  YouTube: estratégias de sucesso para o seu neg...
#
#                                         metadescription  \
# 0     Entenda como o Identity, integrado ao Entity, ...
# 1     Qualquer pessoa com conhecimento em C# que que...
# 2     Faça este curso e entenda como o Entity Framew...
# 3     Nesse curso você vai aprender os primeiros pas...
# 4     Curso prático para você deixar o front-end do ...
# ...                                                 ...
# 1415  Cerca de 34% dos sites na internet foram desen...
# 1416  Wordpress é a plataforma de gerenciamento de c...
# 1417  Xdebug é uma ferramenta poderosa para debug (d...
# 1418                                               None
# 1419  Aprenda estratégias de marketing voltadas para...
#
#                                               categoria  \
# 0     {'nome': 'Programação', 'slug': 'programacao',...
# 1     {'nome': 'Programação', 'slug': 'programacao',...
# 2     {'nome': 'Programação', 'slug': 'programacao',...
# 3     {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
# 4     {'nome': 'Front-end', 'slug': 'front-end', 'or...
# ...                                                 ...
# 1415  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1416  {'nome': 'Front-end', 'slug': 'front-end', 'or...
# 1417  {'nome': 'Programação', 'slug': 'programacao',...
# 1418  {'nome': 'UX & Design', 'slug': 'design-ux', '...
# 1419  {'nome': 'Inovação & Gestão', 'slug': 'inovaca...
#
#                                            subcategoria  quantidade_aulas  \
# 0     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 1     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 6
# 2     {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5
# 3     {'slug': 'transformacao-agil', 'nome': 'Transf...                 6
# 4     {'slug': 'html-css', 'nome': 'HTML e CSS', 'me...                 5
# ...                                                 ...               ...
# 1415  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1416  {'slug': 'wordpress', 'nome': 'WordPress', 'me...                 5
# 1417  {'slug': 'php', 'nome': 'PHP', 'metaTitle': No...                 5
# 1418  {'slug': 'edicao-video', 'nome': 'Edição de Ví...                 5
# 1419  {'slug': 'social-media', 'nome': 'Social Media...                 5
#
#       minutos_video  ...  data_criacao  data_atualizacao  carreiras  \
# 0               131  ...    2023-04-18        2023-05-15         []
# 1               170  ...    2022-12-01        2023-05-04         []
# 2               125  ...    2023-02-03        2023-04-28         []
# 3                80  ...    2019-05-02        2023-02-09         []
# 4               154  ...    2018-04-19        2023-05-18         []
# ...             ...  ...           ...               ...        ...
# 1415            141  ...    2020-03-13        2020-03-13         []
# 1416            164  ...    2020-02-06        2023-05-23         []
# 1417            123  ...    2022-06-06        2022-10-17         []
# 1418            156  ...    2017-08-11        2018-06-28         []
# 1419            159  ...    2022-04-14        2023-04-24         []
#
#                                           alunos_ativos  \
# 0     {'alunos': [{'username': 'felipeedc29', 'nome'...
# 1     {'alunos': [{'username': 'itamarbb1', 'nome': ...
# 2     {'alunos': [{'username': 'hufesouza', 'nome': ...
# 3     {'alunos': [{'username': 'carlos-henrique-s-j'...
# 4     {'alunos': [{'username': 'matheusw3314', 'nome...
# ...                                                 ...
# 1415  {'alunos': [{'username': 'ramon-ubt', 'nome': ...
# 1416  {'alunos': [{'username': 'loivos', 'nome': 'Di...
# 1417  {'alunos': [{'username': 'viniciusvferreira', ...
# 1418  {'alunos': [{'username': 'mariaclaudiapio', 'n...
# 1419  {'alunos': [{'username': 'simeylopes', 'nome':...
#
#                                           requerimentos  alunos_ativos_total  \
# 0                      [.NET 6: relacionando entidades]                413.0
# 1          [HTTP: entendendo a web por baixo dos panos]               1026.0
# 2                         [.NET 6: criando uma web API]                393.0
# 3                                                    []               1821.0
# 4     [HTML e CSS: ambientes de desenvolvimento, est...               1125.0
# ...                                                 ...                  ...
# 1415                   [Wordpress: sites com Elementor]                236.0
# 1416                                                 []                879.0
# 1417              [PHP Exceptions: tratamento de erros]                 66.0
# 1418                                                 []                160.0
# 1419                                                 []                135.0
#
#          categoria_nome   subcategoria_nome                classes  \
# 0           Programação                .NET  Moderadamente Popular
# 1           Programação                .NET  Moderadamente Popular
# 2           Programação                .NET  Moderadamente Popular
# 3     Inovação & Gestão  Transformação Ágil  Moderadamente Popular
# 4             Front-end          HTML e CSS  Moderadamente Popular
# ...                 ...                 ...                    ...
# 1415          Front-end           WordPress  Moderadamente Popular
# 1416          Front-end           WordPress  Moderadamente Popular
# 1417        Programação                 PHP  Moderadamente Popular
# 1418        UX & Design     Edição de Vídeo  Moderadamente Popular
# 1419  Inovação & Gestão        Social Media  Moderadamente Popular
#
#                popularidade
# 0     Moderadamente Popular
# 1             Muito Popular
# 2                   Popular
# 3             Muito Popular
# 4             Muito Popular
# ...                     ...
# 1415          Muito Popular
# 1416          Muito Popular
# 1417  Moderadamente Popular
# 1418          Muito Popular
# 1419                Popular
#
# [1420 rows x 26 columns]

# %% [markdown]
# # Notas

# %%
notas = r3.groupby(by= 'categoria_nome')['nota'].agg(['min', 'max', 'mean', 'std']).rename(columns = {'min': 'Minimo', 'max': 'Maximo', 'mean': 'Media', 'std': 'Desv_p'})
notas.sort_values(by= ['Media','Maximo'], ascending= False, inplace= True)
notas.style.format('{:,.3f}').highlight_max(color= 'lightblue').highlight_min(color = 'lightyellow')
# Out:
# <style type="text/css">
# #T_fcce5_row0_col1, #T_fcce5_row0_col2, #T_fcce5_row2_col0, #T_fcce5_row4_col0, #T_fcce5_row5_col1, #T_fcce5_row6_col3 {
#   background-color: lightblue;
# }
# #T_fcce5_row2_col1, #T_fcce5_row2_col3, #T_fcce5_row4_col1, #T_fcce5_row5_col0, #T_fcce5_row6_col0, #T_fcce5_row6_col2 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_fcce5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcce5_level0_col0" class="col_heading level0 col0" >Minimo</th>
#       <th id="T_fcce5_level0_col1" class="col_heading level0 col1" >Maximo</th>
#       <th id="T_fcce5_level0_col2" class="col_heading level0 col2" >Media</th>
#       <th id="T_fcce5_level0_col3" class="col_heading level0 col3" >Desv_p</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >categoria_nome</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcce5_level0_row0" class="row_heading level0 row0" >UX & Design</th>
#       <td id="T_fcce5_row0_col0" class="data row0 col0" >8.300</td>
#       <td id="T_fcce5_row0_col1" class="data row0 col1" >9.700</td>
#       <td id="T_fcce5_row0_col2" class="data row0 col2" >9.262</td>
#       <td id="T_fcce5_row0_col3" class="data row0 col3" >0.174</td>
#     </tr>
#     <tr>
#       <th id="T_fcce5_level0_row1" class="row_heading level0 row1" >Programação</th>
#       <td id="T_fcce5_row1_col0" class="data row1 col0" >8.500</td>
#       <td id="T_fcce5_row1_col1" class="data row1 col1" >9.600</td>
#       <td id="T_fcce5_row1_col2" class="data row1 col2" >9.260</td>
#       <td id="T_fcce5_row1_col3" class="data row1 col3" >0.186</td>
#     </tr>
#     <tr>
#       <th id="T_fcce5_level0_row2" class="row_heading level0 row2" >Inovação & Gestão</th>
#       <td id="T_fcce5_row2_col0" class="data row2 col0" >8.700</td>
#       <td id="T_fcce5_row2_col1" class="data row2 col1" >9.500</td>
#       <td id="T_fcce5_row2_col2" class="data row2 col2" >9.226</td>
#       <td id="T_fcce5_row2_col3" class="data row2 col3" >0.131</td>
#     </tr>
#     <tr>
#       <th id="T_fcce5_level0_row3" class="row_heading level0 row3" >Data Science</th>
#       <td id="T_fcce5_row3_col0" class="data row3 col0" >8.400</td>
#       <td id="T_fcce5_row3_col1" class="data row3 col1" >9.600</td>
#       <td id="T_fcce5_row3_col2" class="data row3 col2" >9.215</td>
#       <td id="T_fcce5_row3_col3" class="data row3 col3" >0.195</td>
#     </tr>
#     <tr>
#       <th id="T_fcce5_level0_row4" class="row_heading level0 row4" >DevOps</th>
#       <td id="T_fcce5_row4_col0" class="data row4 col0" >8.700</td>
#       <td id="T_fcce5_row4_col1" class="data row4 col1" >9.500</td>
#       <td id="T_fcce5_row4_col2" class="data row4 col2" >9.213</td>
#       <td id="T_fcce5_row4_col3" class="data row4 col3" >0.145</td>
#     </tr>
#     <tr>
#       <th id="T_fcce5_level0_row5" class="row_heading level0 row5" >Front-end</th>
#       <td id="T_fcce5_row5_col0" class="data row5 col0" >0.000</td>
#       <td id="T_fcce5_row5_col1" class="data row5 col1" >9.700</td>
#       <td id="T_fcce5_row5_col2" class="data row5 col2" >9.138</td>
#       <td id="T_fcce5_row5_col3" class="data row5 col3" >0.909</td>
#     </tr>
#     <tr>
#       <th id="T_fcce5_level0_row6" class="row_heading level0 row6" >Mobile</th>
#       <td id="T_fcce5_row6_col0" class="data row6 col0" >0.000</td>
#       <td id="T_fcce5_row6_col1" class="data row6 col1" >9.600</td>
#       <td id="T_fcce5_row6_col2" class="data row6 col2" >9.104</td>
#       <td id="T_fcce5_row6_col3" class="data row6 col3" >0.933</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Quantidade de Cursos

# %%
cursos = r3.value_counts(subset= ['categoria_nome', 'subcategoria_nome'], normalize= True)
prop_cursos = pd.DataFrame(cursos)
prop_cursos.columns = ['proporcao']
prop_cursos.style.format('{:.2%}').bar(subset = 'proporcao',vmin= 0.0005, color = 'lightgreen')
# Out:
# <style type="text/css">
# #T_cc640_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_cc640_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 92.2%, transparent 92.2%);
# }
# #T_cc640_row2_col0, #T_cc640_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 86.4%, transparent 86.4%);
# }
# #T_cc640_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 84.4%, transparent 84.4%);
# }
# #T_cc640_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 82.5%, transparent 82.5%);
# }
# #T_cc640_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 68.8%, transparent 68.8%);
# }
# #T_cc640_row7_col0, #T_cc640_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 61.0%, transparent 61.0%);
# }
# #T_cc640_row9_col0, #T_cc640_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 57.1%, transparent 57.1%);
# }
# #T_cc640_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 55.2%, transparent 55.2%);
# }
# #T_cc640_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 49.3%, transparent 49.3%);
# }
# #T_cc640_row13_col0, #T_cc640_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 47.4%, transparent 47.4%);
# }
# #T_cc640_row15_col0, #T_cc640_row16_col0, #T_cc640_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 45.4%, transparent 45.4%);
# }
# #T_cc640_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 43.5%, transparent 43.5%);
# }
# #T_cc640_row19_col0, #T_cc640_row20_col0, #T_cc640_row21_col0, #T_cc640_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 37.6%, transparent 37.6%);
# }
# #T_cc640_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 35.7%, transparent 35.7%);
# }
# #T_cc640_row24_col0, #T_cc640_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 33.7%, transparent 33.7%);
# }
# #T_cc640_row26_col0, #T_cc640_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 31.8%, transparent 31.8%);
# }
# #T_cc640_row28_col0, #T_cc640_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 29.8%, transparent 29.8%);
# }
# #T_cc640_row30_col0, #T_cc640_row31_col0, #T_cc640_row32_col0, #T_cc640_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 27.9%, transparent 27.9%);
# }
# #T_cc640_row34_col0, #T_cc640_row35_col0, #T_cc640_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 25.9%, transparent 25.9%);
# }
# #T_cc640_row37_col0, #T_cc640_row38_col0, #T_cc640_row39_col0, #T_cc640_row40_col0, #T_cc640_row41_col0, #T_cc640_row42_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 24.0%, transparent 24.0%);
# }
# #T_cc640_row43_col0, #T_cc640_row44_col0, #T_cc640_row45_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.0%, transparent 22.0%);
# }
# #T_cc640_row46_col0, #T_cc640_row47_col0, #T_cc640_row48_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 20.1%, transparent 20.1%);
# }
# #T_cc640_row49_col0, #T_cc640_row50_col0, #T_cc640_row51_col0, #T_cc640_row52_col0, #T_cc640_row53_col0, #T_cc640_row54_col0, #T_cc640_row55_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 18.1%, transparent 18.1%);
# }
# #T_cc640_row56_col0, #T_cc640_row57_col0, #T_cc640_row58_col0, #T_cc640_row59_col0, #T_cc640_row60_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 16.2%, transparent 16.2%);
# }
# #T_cc640_row61_col0, #T_cc640_row62_col0, #T_cc640_row63_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.2%, transparent 14.2%);
# }
# #T_cc640_row64_col0, #T_cc640_row65_col0, #T_cc640_row66_col0, #T_cc640_row67_col0, #T_cc640_row68_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 12.3%, transparent 12.3%);
# }
# #T_cc640_row69_col0, #T_cc640_row70_col0, #T_cc640_row71_col0, #T_cc640_row72_col0, #T_cc640_row73_col0, #T_cc640_row74_col0, #T_cc640_row75_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 10.3%, transparent 10.3%);
# }
# #T_cc640_row76_col0, #T_cc640_row77_col0, #T_cc640_row78_col0, #T_cc640_row79_col0, #T_cc640_row80_col0, #T_cc640_row81_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 8.4%, transparent 8.4%);
# }
# #T_cc640_row82_col0, #T_cc640_row83_col0, #T_cc640_row84_col0, #T_cc640_row85_col0, #T_cc640_row86_col0, #T_cc640_row87_col0, #T_cc640_row88_col0, #T_cc640_row89_col0, #T_cc640_row90_col0, #T_cc640_row91_col0, #T_cc640_row92_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 6.4%, transparent 6.4%);
# }
# #T_cc640_row93_col0, #T_cc640_row94_col0, #T_cc640_row95_col0, #T_cc640_row96_col0, #T_cc640_row97_col0, #T_cc640_row98_col0, #T_cc640_row99_col0, #T_cc640_row100_col0, #T_cc640_row101_col0, #T_cc640_row102_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 4.5%, transparent 4.5%);
# }
# #T_cc640_row103_col0, #T_cc640_row104_col0, #T_cc640_row105_col0, #T_cc640_row106_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 2.5%, transparent 2.5%);
# }
# #T_cc640_row107_col0, #T_cc640_row108_col0, #T_cc640_row109_col0, #T_cc640_row110_col0, #T_cc640_row111_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 0.6%, transparent 0.6%);
# }
# </style>
# <table id="T_cc640">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc640_level0_col0" class="col_heading level0 col0" >proporcao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >categoria_nome</th>
#       <th class="index_name level1" >subcategoria_nome</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc640_level0_row0" class="row_heading level0 row0" >UX & Design</th>
#       <th id="T_cc640_level1_row0" class="row_heading level1 row0" >Design Gráfico</th>
#       <td id="T_cc640_row0_col0" class="data row0 col0" >3.66%</td>
#     </tr>
#     <tr>
#       <th id="T_cc640_level0_row1" class="row_heading level0 row1" rowspan="2">Programação</th>
#       <th id="T_cc640_level1_row1" class="row_heading level1 row1" >Java</th>
#       <td id="T_cc640_row1_col0" class="data row1 col0" >3.38%</td>
#     </tr>
#     <tr>
#       <th id="T_cc640_level1_row2" class="row_heading level1 row2" >PHP</th>
#       <td id="T_cc640_row2_col0" class="data row2 col0" >3.17%</td>
#     </tr>
#     <tr>
#       <th id="T_cc640_level0_row3" class="row_heading level0 row3" rowspan="2">Data Science</th>
#       <th id="T_cc640_level1_row3" class="row_heading level1 row3" >Business Intelligence</th>
#       <td id="T_cc640_row3_col0" class="data row3 col0" >3.17%</td>
#     </tr>
#     <tr>
#       <th id="T_cc640_level1_row4" class="row_heading level1 row4" >Machine Learning</th>
#       <td id="T_cc640_row4_col0" class="data row4 col0" >3.10%</td>
#     </tr>
#     <tr>
#       <th id="T_cc640_level0_row5" class="row_heading level0 row5" >Mobile</th>
#       <th id="T_cc640_level1_row5" class="row_heading level1 row5" >Android</th>
#       <td id="T_cc640_row5_col0" class="data row5 col0" >3.03%</td>
#     </tr>
#     <tr>
#       <th id="T_cc640_level0_row6" class="row_heading level0 row6" >Front-end</th>
#       <th id="T_cc640_level1_row6" class="row_heading level1 row6" >React</th>
#       <td id="T_cc640_row6_col0" class="data row6 col0" >2.54%</td>
#     </tr>
#     <tr>
#       <th id="T_cc640_level0_row7" class="row_heading level0 row7" >Data Science</th>
#       <th id="T_cc640_level1_row7" class="row_heading level1 row7" >SQL e Banco de Dados</th>
#       <td id="T_cc640_row7_col0" class="data row7 col0" >2.25%</td>
#     </tr>
#     <tr>
#       <th id="T_cc640_level0_row8" class="row_heading level0 row8" >UX & Design</th>
#       <th id="T_cc640_level1_row8" class="row_heading level1 row8" >Pintura Digital</th>
#       <td id="T_cc640_row8_col0" class="data row8 c
