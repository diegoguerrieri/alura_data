# %% [markdown]
# * Importando Numpy e Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# * Preparando os dados

# %%
tam = 10000
ids = np.arange(1, tam + 1, 1, dtype=int)
idades = np.random.randint(low= 18, high= 126, size= tam, dtype= int)
lista_sexo = np.array(['M', 'F'])
sexo = np.random.choice(lista_sexo, size= tam)
lista_estados_civis = np.array(['solteiro', 'casado', 'divorciado', 'viuvo'])
estados_civis = np.random.choice(lista_estados_civis, size= tam)
sinistros = np.random.randint(low= 0, high= 2, size= tam, dtype= int)
premios = np.around(np.random.random(size=tam) * 10000, 2)

# dicionario = {
#     'ids': ids,
#     'idades': idades,
#     'sexo': sexo,
#     'estados_civis': estados_civis,
#     'sinistros': sinistros,
#     'premios': premios
# }

tab = pd.DataFrame([idades, sexo, estados_civis, sinistros, premios], index = ['idades', 'sexo', 'estados_civis', 'sinistros', 'premios'])
# tab.columns = ['ids', 'idades', 'sexo', 'estados_civis', 'sinistros', 'premios']
tab.columns = ids
tab
# tab.set_index('ids', inplace= True)
# tab
dicionario = tab.to_dict()
dicionario

tab.T

# dados = [
#     {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
#     {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
#     {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
# ]

# dataset = pd.DataFrame(dados)
# dado = dataset.to_dict('list')
# dado
# Out:
#       idades sexo estados_civis sinistros  premios
# 1         36    M      solteiro         1  1538.89
# 2         95    F        casado         0  5655.97
# 3         45    F    divorciado         1  8290.44
# 4        124    F         viuvo         0  8468.84
# 5         29    M      solteiro         1  3022.58
# ...      ...  ...           ...       ...      ...
# 9996      39    M      solteiro         1   245.06
# 9997      40    M         viuvo         1  2142.19
# 9998      73    M        casado         0  7629.26
# 9999     107    F         viuvo         1  1736.18
# 10000     49    F        casado         1  9768.75
#
# [10000 rows x 5 columns]

# %% [markdown]
# * Visualização do DataFrame

# %%
tab.head()
# Out:
#                    1         2        3           4         5           6     \
# idades               95       105       36          42        62          95
# sexo                  F         M        M           M         M           M
# estados_civis  solteiro  solteiro    viuvo  divorciado  solteiro  divorciado
# sinistros             1         1        0           1         1           0
# premios         4798.18   3506.91  7554.66     2997.09   8347.01      448.74
#
#                   7        8       9        10    ...      991       992   \
# idades              54       88     100       32  ...        25       101
# sexo                 M        M       M        F  ...         F         M
# estados_civis   casado   casado  casado   casado  ...  solteiro  solteiro
# sinistros            0        0       0        1  ...         0         0
# premios        4495.66  1756.04  121.76  9504.18  ...   4414.14   5679.79
#
#                      993      994      995         996      997         998   \
# idades                 25      104       93          63       65          87
# sexo                    M        M        F           F        M           M
# estados_civis  divorciado   casado    viuvo  divorciado    viuvo  divorciado
# sinistros               0        0        1           0        1           0
# premios           4269.33  2404.09  3961.21     2944.03  1895.22     7763.87
#
#                   999      1000
# idades              20      102
# sexo                 F        F
# estados_civis    viuvo    viuvo
# sinistros            1        0
# premios        8854.04  5831.69
#
# [5 rows x 1000 columns]

# %% [markdown]
# * Filtrando clientes com idades maiores do que 30

# %%
# tab[tab.idades > 30]
# tab[tab['idades'] > 30]
tab.query('idades > 30')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\scope.py:197, in Scope.resolve(self, key, is_local)
#     196 if self.has_resolvers:
# --> 197     return self.resolvers[key]
#     199 # if we're here that means that we have no locals and we also have
#     200 # no resolvers
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\collections\__init__.py:941, in ChainMap.__getitem__(self, key)
#     940         pass
# --> 941 return self.__missing__(key)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\collections\__init__.py:933, in ChainMap.__missing__(self, key)
#     932 def __missing__(self, key):
# --> 933     raise KeyError(key)
#
# KeyError: 'idades'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\scope.py:208, in Scope.resolve(self, key, is_local)
#     204 try:
#     205     # last ditch effort we look in temporaries
#     206     # these are created when parsing indexing expressions
#     207     # e.g., df[df > 0]
# --> 208     return self.temps[key]
#     209 except KeyError as err:
#     210     # runtime import because ops imports from scope
#
# KeyError: 'idades'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# c:\Users\dguerrieri\Desktop\alura_data\semana_7.ipynb Célula 8 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/dguerrieri/Desktop/alura_data/semana_7.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # tab[tab.idades > 30]
#       <a href='vscode-notebook-cell:/c%3A/Users/dguerrieri/Desktop/alura_data/semana_7.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> # tab[tab['idades'] > 30]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dguerrieri/Desktop/alura_data/semana_7.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> tab.query('idades > 30')
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4111, in DataFrame.query(self, expr, inplace, **kwargs)
#    4109 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4110 kwargs["target"] = None
# -> 4111 res = self.eval(expr, **kwargs)
#    4113 try:
#    4114     result = self.loc[res]
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4240, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4237     kwargs["target"] = self
#    4238 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4240 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\eval.py:350, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     341 # get our (possibly passed-in) scope
#     342 env = ensure_scope(
#     343     level + 1,
#     344     global_dict=global_dict,
#    (...)
#     347     target=target,
#     348 )
# --> 350 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     352 # construct the engine and evaluate the parsed expression
#     353 eng = ENGINES[engine]
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:811, in Expr.__init__(self, expr, engine, parser, env, level)
#     809 self.parser = parser
#     810 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 811 self.terms = self.parse()
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:830, in Expr.parse(self)
#     826 def parse(self):
#     827     """
#     828     Parse an expression.
#     829     """
# --> 830     return self._visitor.visit(self.expr)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:723, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     721     op = self.translate_In(ops[0])
#     722     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 723     return self.visit(binop)
#     725 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     726 left = node.left
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:536, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     535 def visit_BinOp(self, node, **kwargs):
# --> 536     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     537     left, right = self._maybe_downcast_constants(left, right)
#     538     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:456, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     454 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     455     if left is None:
# --> 456         left = self.visit(node.left, side="left")
#     457     if right is None:
#     458         right = self.visit(node.right, side="right")
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expr.py:549, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     548 def visit_Name(self, node, **kwargs):
# --> 549     return self.term_type(node.id, self.env, **kwargs)
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\ops.py:98, in Term.__init__(self, name, env, side, encoding)
#      96 tname = str(name)
#      97 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 98 self._value = self._resolve_name()
#      99 self.encoding = encoding
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     114 def _resolve_name(self):
# --> 115     res = self.env.resolve(self.local_name, is_local=self.is_local)
#     116     self.update(res)
#     118     if hasattr(res, "ndim") and res.ndim > 2:
#
# File c:\Users\dguerrieri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\scope.py:213, in Scope.resolve(self, key, is_local)
#     209 except KeyError as err:
#     210     # runtime import because ops imports from scope
#     211     from pandas.core.computation.ops import UndefinedVariableError
# --> 213     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'idades' is not defined

# %% [markdown]
# * Filtrando clientes sem sinistros

# %%
tab.query('sinistros == 0')
# Out:
#            ids idades sexo estados_civis sinistros  premios
# 0            1    111    M         viuvo         0   3218.6
# 1            2     67    F    divorciado         0  9305.14
# 4            5     43    M    divorciado         0  1027.89
# 7            8     18    M        casado         0  8975.05
# 9           10     40    F         viuvo         0  4543.73
# ...        ...    ...  ...           ...       ...      ...
# 999991  999992     69    M      solteiro         0  8697.81
# 999993  999994     29    F        casado         0  9836.04
# 999994  999995    121    M    divorciado         0  4776.39
# 999995  999996     76    F    divorciado         0  3828.75
# 999998  999999     64    M         viuvo         0   8952.5
#
# [499174 rows x 6 columns]

# %% [markdown]
# * Exibir Idade e Prêmio

# %%
tab[['idades', 'premios']]
tab.loc[:, ['idades', 'premios']]
tab.iloc[:, [1,5]]
# Out:
#        idades  premios
# 0         111   3218.6
# 1          67  9305.14
# 2          83   338.89
# 3          35  2919.67
# 4          43  1027.89
# ...       ...      ...
# 999995     76  3828.75
# 999996     78   486.95
# 999997    121  3641.83
# 999998     64   8952.5
# 999999     34  9989.44
#
# [1000000 rows x 2 columns]

# %% [markdown]
# * Exportando os dados para o csv

# %%
tab.to_csv(path_or_buf= 'dados.csv', index= False)

# %% [markdown]
# * Carregue esses dados de um csv

# %%
infos = pd.read_csv(filepath_or_buffer= 'dados.csv')
infos
# Out:
#             ids  idades sexo estados_civis  sinistros  premios
# 0             1     111    M         viuvo          0  3218.60
# 1             2      67    F    divorciado          0  9305.14
# 2             3      83    M    divorciado          1   338.89
# 3             4      35    M    divorciado          1  2919.67
# 4             5      43    M    divorciado          0  1027.89
# ...         ...     ...  ...           ...        ...      ...
# 999995   999996      76    F    divorciado          0  3828.75
# 999996   999997      78    F      solteiro          1   486.95
# 999997   999998     121    M        casado          1  3641.83
# 999998   999999      64    M         viuvo          0  8952.50
# 999999  1000000      34    F    divorciado          1  9989.44
#
# [1000000 rows x 6 columns]

# %% [markdown]
# * Categorizando idades

# %%
for index, row in tab.iterrows():
    if(row['idades'] < 31):
        tab.loc[index, 'faixa_idade'] = 'Jovem'
    elif(row['idades'] < 46):
        tab.loc[index, 'faixa_idade'] = 'Adulto'
    else:
        tab.loc[index, 'faixa_idade'] = 'Senior'

tab

def faixas(idade):
    for i in idade:
        if i < 31:
            return 'Jovem'
        elif i < 46:
            return 'Adulto'
        else:
            return 'Senior'

tab['faixa_idade2'] = tab[['idades']].apply(faixas, axis= 1)
tab

def faixas(tabelas):
    if tabelas['idades'] < 31:
        return 'Jovem'
    elif tabelas['idades'] < 46:
        return 'Adulto'
    else:
        return 'Senior'

tab['faixa_idade3'] = tab.apply(faixas, axis= 1)
tab
# Out:
#             ids idades sexo estados_civis sinistros  premios faixa_idade  \
# 0             1    111    M         viuvo         0   3218.6      Senior
# 1             2     67    F    divorciado         0  9305.14      Senior
# 2             3     83    M    divorciado         1   338.89      Senior
# 3             4     35    M    divorciado         1  2919.67      Adulto
# 4             5     43    M    divorciado         0  1027.89      Adulto
# ...         ...    ...  ...           ...       ...      ...         ...
# 999995   999996     76    F    divorciado         0  3828.75      Senior
# 999996   999997     78    F      solteiro         1   486.95      Senior
# 999997   999998    121    M        casado         1  3641.83      Senior
# 999998   999999     64    M         viuvo         0   8952.5      Senior
# 999999  1000000     34    F    divorciado         1  9989.44      Adulto
#
#        faixa_idade2 faixa_idade3
# 0            Senior       Senior
# 1            Senior       Senior
# 2            Senior       Senior
# 3            Adulto       Adulto
# 4            Adulto       Adulto
# ...             ...          ...
# 999995       Senior       Senior
# 999996       Senior       Senior
# 999997       Senior       Senior
# 999998       Senior       Senior
# 999999       Adulto       Adulto
#
# [1000000 rows x 9 columns]

# %% [markdown]
# * Aplicando descontos

# %%
import time
start_np = time.time()
lista = [((tab['faixa_idade'] == 'Jovem') & (tab['sinistros'] == 0)), 
        (((tab['faixa_idade'] == 'Adulto') | (tab['faixa_idade'] == 'Senior')) & (tab['sinistros'] == 0))]
lista
desconto = [0.05, 0.1]
desconto
tab['desconto'] = np.select(condlist= lista, choicelist= desconto, default= 0) * tab['premios']
tab['premio_desc'] = tab['premios'] - tab['desconto']
end_np = time.time()
print(f'np.select : {(end_np - start_np)}')

start_trad = time.time()
tab.loc[(tab['faixa_idade'] == 'Jovem') & (tab['sinistros'] == 0), 'premio_desc2'] = 0.95 * tab['premios']
tab.loc[(tab['faixa_idade'] == 'Adulto') & (tab['sinistros'] == 0), 'premio_desc2'] = 0.9 * tab['premios']
tab.loc[(tab['faixa_idade'] == 'Senior') & (tab['sinistros'] == 0), 'premio_desc2'] = 0.9 * tab['premios']
tab.loc[(tab['premio_desc2'].isnull()), 'premio_desc2'] = tab['premios']
# tab['premio_desc2'].fillna(tab['premios'], inplace = True)
end_trad = time.time()
print(f'met_trad : {(end_trad - start_trad)}')

start_cut = time.time()
tab['desconto1'] = pd.cut(tab['idades'], [18, 30, 126], labels= [0.05, 0.1])
tab['desconto1'] = tab['desconto1'].astype(float)
tab['premio_desc3'] = (1 - tab['desconto1'] * (1 - tab['sinistros'])) * tab['premios']
# tab['premio_desc3'] = (1 - tab['desconto1'][tab['sinistros'] == 0]) * tab['premios']
# tab['premio_desc3'].fillna(tab['premios'], inplace = True)
end_cut = time.time()
print(f'met_cut : {end_cut - start_cut}')

start_dic = time.time()
tab['faixa_idade4'] = pd.cut(tab['idades'], [18, 30, 45, 126], labels= ["Jovem", "Adulto", "Senior"],include_lowest = True)
dic_fator = {
    'Jovem': 0.95,
    'Adulto': 0.9,
    'Senior': 0.9
}

     
tab['premio_desc4'] = tab['faixa_idade4'].map(dic_fator) * tab['premios'] * (tab['sinistros'] == 0)
end_dic = time.time()
print(f'met_dic : {end_dic - start_dic}')

start_apply = time.time()
def calcular_desconto(row):
    if row['sinistros'] == 0:
        if row['faixa_idade'] in ['Adulto', 'Sênior']:
            return row['premios'] * 0.9
        elif row['faixa_idade'] == 'Jovem':
            return row['premios'] * 0.95
        else:
          return row['faixa_idade']
          
    return row['premios']

tab['desconto2'] = tab.apply(calcular_desconto, axis=1)
end_apply = time.time()
print(f'met_apply : {end_apply - start_apply}')
# Out:
# np.select : 1.6574747562408447
# met_trad : 1.3804888725280762
# met_cut : 3.644333839416504
# met_dic : 1.0104670524597168
# met_apply : 22.51912021636963
