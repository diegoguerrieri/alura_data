# %% [markdown]
# ## Importando o Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Carregando dados

# %%
dados = pd.read_csv('dados2.csv')
dados.head()
# Out:
#    CONCLIENTE dataNascimentoCliente sexoCliente  CONINSCRICAO  CONPRODUTO  \
# 0     1750926            1977-10-06           M      16013091         895
# 1     1750926            1977-10-06           M      16013091         895
# 2     1750926            1977-10-06           M      16013091         895
# 3     4300961            1957-04-15           M      16010702         895
# 4     3073128            1964-11-15           M      16013359         895
#
#   periodicidadeCobranca  parcelamento  CONITEMCONTRATADO  \
# 0                MENSAL             1           94352363
# 1                MENSAL             1           94352363
# 2                MENSAL             1           94352363
# 3                MENSAL             1           94352382
# 4                MENSAL             1           94352411
#
#    codigoSistemaItemContratado dataInicioVigenciaCobertura  ...  \
# 0                       203045                  2022-01-06  ...
# 1                       203045                  2022-01-06  ...
# 2                       203045                  2022-01-06  ...
# 3                       203045                  2022-01-06  ...
# 4                       203045                  2022-01-11  ...
#
#    prazoDecrescimoItemContratado  prazoCertoRendaItemContratado  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    prazoMinimoGarantidoRendaItemContratado  indiceReajusteItemContratado  \
# 0                                      NaN                          IPCA
# 1                                      NaN                          IPCA
# 2                                      NaN                          IPCA
# 3                                      NaN                          IPCA
# 4                                      NaN                          IPCA
#
#    valorCapitalSeguradoItemContratadoInicial CONITEMCONTRATADOBENEFICIARIO  \
# 0                                  100000.00                     1840596.0
# 1                                  100000.00                     1840697.0
# 2                                  100000.00                     1841208.0
# 3                                   50000.00                     1841180.0
# 4                                  342179.29                           NaN
#
#    percentualParticipacaoBeneficio  CONBENEFICIARIO  \
# 0                             30.0        3616260.0
# 1                             40.0        3616259.0
# 2                             30.0        3616261.0
# 3                            100.0        3475459.0
# 4                              NaN              NaN
#
#    dataNascimentoBeneficiario  sexoBeneficiario
# 0                  2006-04-14          FEMININO
# 1                  1976-05-29          FEMININO
# 2                  1997-11-25         MASCULINO
# 3                  1965-09-15     NÃO INFORMADO
# 4                         NaN               NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Separando os dados

# %%
cliente = pd.read_csv('dados2.csv', usecols= [0,1,2]).rename(columns= {'CONCLIENTE': 'id', 'dataNascimentoCliente': 'data_nascimento', 'sexoCliente': 'sexo'})
cliente = cliente[~cliente['id'].isna()]
cliente.head()

inscricao = dados.iloc[:,[3, 0, 4, 5]]
inscricao.columns = ['id', 'cliente_id', 'produto_id', 'periodicidade']
inscricao.head()

itemcontratado = dados[['CONITEMCONTRATADO', 'CONINSCRICAO', 'codigoSistemaItemContratado', 'dataInicioVigenciaCobertura', 'prazoCobertura', 'prazoContribuicao', 'prazoCertoRendaItemContratado', 'prazoMinimoGarantidoRendaItemContratado', 'prazoDecrescimoItemContratado', 'indiceReajusteItemContratado', 'valorCapitalSeguradoItemContratadoInicial']]
itemcontratado.columns = ['id', 'inscricao_id', 'itemproduto_id', 'data_assinatura', 'prazo_cobertura', 'prazo_pagamento', 'prazo_renda', 'prazo_certo_renda', 'prazo_decrescimo', 'indice_reajuste', 'beneficio_inicial']
itemcontratado = itemcontratado[~itemcontratado['id'].isna()]
itemcontratado.head()

itembeneciario = dados[['CONITEMCONTRATADOBENEFICIARIO', 'CONITEMCONTRATADO', 'CONBENEFICIARIO', 'percentualParticipacaoBeneficio']]
itembeneciario.columns = ['id', 'itemcontratado_id', 'beneficiario_id', 'percentual_beneficio']
itembeneciario = itembeneciario[~itembeneciario['id'].isna()]
itembeneciario.head()

beneficiario = dados[['CONBENEFICIARIO', 'dataNascimentoBeneficiario', 'sexoBeneficiario']]
beneficiario.columns = ['id', 'data_nascimento', 'sexo']
beneficiario = beneficiario[~beneficiario['id'].isna()]
beneficiario.head()
# Out:
#           id data_nascimento           sexo
# 0  3616260.0      2006-04-14       FEMININO
# 1  3616259.0      1976-05-29       FEMININO
# 2  3616261.0      1997-11-25      MASCULINO
# 3  3475459.0      1965-09-15  NÃO INFORMADO
# 5  3615870.0      1983-05-21      MASCULINO

# %% [markdown]
# ## Trabalhando com SQL

# %%
import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, inspect

# %%
engine = create_engine('sqlite:///dados.db')

cliente.to_sql('cliente', engine, index= False, if_exists= 'replace')
inscricao.to_sql('inscricao', engine, index= False, if_exists= 'replace')
itemcontratado.to_sql('itemcontratado', engine, index = False, if_exists= 'replace')
itembeneciario.to_sql('itembeneciario', engine, index = False, if_exists= 'replace')
beneficiario.to_sql('beneficiario', engine, index = False, if_exists= 'replace')


inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['beneficiario', 'cliente', 'inscricao', 'itembeneciario', 'itemcontratado']

# %% [markdown]
# ## Quantidade de Clientes e de beneficiários por sexo

# %%
query = """SELECT A.*, B.CONT_CLI FROM (SELECT CASE WHEN SEXO = "MASCULINO" THEN "M" 
                                                    WHEN SEXO = "FEMININO" THEN "F" 
                                                    ELSE "NA" END AS SEXO, 
                                               COUNT(*) AS CONT_BENEF 
                                        FROM BENEFICIARIO GROUP BY CASE WHEN SEXO = "MASCULINO" THEN "M" 
                                                                        WHEN SEXO = "FEMININO" THEN "F" ELSE "NA" END) A
           LEFT JOIN (SELECT SEXO, COUNT(*) AS CONT_CLI FROM CLIENTE GROUP BY SEXO) B ON A.SEXO = B.SEXO"""

pd.read_sql(query, engine)
# Out:
#   SEXO  CONT_BENEF  CONT_CLI
# 0    F         130     421.0
# 1    M         432     579.0
# 2   NA         202       NaN

# %% [markdown]
# ## Clientes com mais inscricoes

# %%
query = """SELECT CLIENTE_ID, COUNT(*) AS QTD 
           FROM INSCRICAO 
           GROUP BY CLIENTE_ID
           HAVING QTD > 1
           ORDER BY COUNT(*) DESC"""
           
pd.read_sql(query, engine).style.highlight_max(color= 'lightblue', subset = 'QTD').highlight_min(color = 'lightyellow', subset = 'QTD')
# Out:
# <style type="text/css">
# #T_e93cc_row0_col1, #T_e93cc_row1_col1, #T_e93cc_row2_col1 {
#   background-color: lightblue;
# }
# #T_e93cc_row102_col1, #T_e93cc_row103_col1, #T_e93cc_row104_col1, #T_e93cc_row105_col1, #T_e93cc_row106_col1, #T_e93cc_row107_col1, #T_e93cc_row108_col1, #T_e93cc_row109_col1, #T_e93cc_row110_col1, #T_e93cc_row111_col1, #T_e93cc_row112_col1, #T_e93cc_row113_col1, #T_e93cc_row114_col1, #T_e93cc_row115_col1, #T_e93cc_row116_col1, #T_e93cc_row117_col1, #T_e93cc_row118_col1, #T_e93cc_row119_col1, #T_e93cc_row120_col1, #T_e93cc_row121_col1, #T_e93cc_row122_col1, #T_e93cc_row123_col1, #T_e93cc_row124_col1, #T_e93cc_row125_col1, #T_e93cc_row126_col1, #T_e93cc_row127_col1, #T_e93cc_row128_col1, #T_e93cc_row129_col1, #T_e93cc_row130_col1, #T_e93cc_row131_col1, #T_e93cc_row132_col1, #T_e93cc_row133_col1, #T_e93cc_row134_col1, #T_e93cc_row135_col1, #T_e93cc_row136_col1, #T_e93cc_row137_col1, #T_e93cc_row138_col1, #T_e93cc_row139_col1, #T_e93cc_row140_col1, #T_e93cc_row141_col1, #T_e93cc_row142_col1, #T_e93cc_row143_col1, #T_e93cc_row144_col1, #T_e93cc_row145_col1, #T_e93cc_row146_col1, #T_e93cc_row147_col1, #T_e93cc_row148_col1, #T_e93cc_row149_col1, #T_e93cc_row150_col1, #T_e93cc_row151_col1, #T_e93cc_row152_col1, #T_e93cc_row153_col1, #T_e93cc_row154_col1, #T_e93cc_row155_col1, #T_e93cc_row156_col1, #T_e93cc_row157_col1, #T_e93cc_row158_col1, #T_e93cc_row159_col1, #T_e93cc_row160_col1, #T_e93cc_row161_col1, #T_e93cc_row162_col1, #T_e93cc_row163_col1, #T_e93cc_row164_col1, #T_e93cc_row165_col1, #T_e93cc_row166_col1, #T_e93cc_row167_col1, #T_e93cc_row168_col1, #T_e93cc_row169_col1, #T_e93cc_row170_col1, #T_e93cc_row171_col1, #T_e93cc_row172_col1, #T_e93cc_row173_col1, #T_e93cc_row174_col1, #T_e93cc_row175_col1, #T_e93cc_row176_col1, #T_e93cc_row177_col1, #T_e93cc_row178_col1, #T_e93cc_row179_col1, #T_e93cc_row180_col1, #T_e93cc_row181_col1, #T_e93cc_row182_col1, #T_e93cc_row183_col1, #T_e93cc_row184_col1, #T_e93cc_row185_col1, #T_e93cc_row186_col1, #T_e93cc_row187_col1, #T_e93cc_row188_col1, #T_e93cc_row189_col1, #T_e93cc_row190_col1, #T_e93cc_row191_col1, #T_e93cc_row192_col1, #T_e93cc_row193_col1, #T_e93cc_row194_col1, #T_e93cc_row195_col1, #T_e93cc_row196_col1, #T_e93cc_row197_col1, #T_e93cc_row198_col1, #T_e93cc_row199_col1, #T_e93cc_row200_col1, #T_e93cc_row201_col1, #T_e93cc_row202_col1, #T_e93cc_row203_col1, #T_e93cc_row204_col1, #T_e93cc_row205_col1, #T_e93cc_row206_col1, #T_e93cc_row207_col1, #T_e93cc_row208_col1, #T_e93cc_row209_col1, #T_e93cc_row210_col1, #T_e93cc_row211_col1, #T_e93cc_row212_col1, #T_e93cc_row213_col1, #T_e93cc_row214_col1, #T_e93cc_row215_col1, #T_e93cc_row216_col1 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_e93cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e93cc_level0_col0" class="col_heading level0 col0" >cliente_id</th>
#       <th id="T_e93cc_level0_col1" class="col_heading level0 col1" >QTD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e93cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e93cc_row0_col0" class="data row0 col0" >7583711</td>
#       <td id="T_e93cc_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e93cc_row1_col0" class="data row1 col0" >4740226</td>
#       <td id="T_e93cc_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e93cc_row2_col0" class="data row2 col0" >1997789</td>
#       <td id="T_e93cc_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e93cc_row3_col0" class="data row3 col0" >7619720</td>
#       <td id="T_e93cc_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e93cc_row4_col0" class="data row4 col0" >7551345</td>
#       <td id="T_e93cc_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e93cc_row5_col0" class="data row5 col0" >7523381</td>
#       <td id="T_e93cc_row5_col1" class="data row5 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e93cc_row6_col0" class="data row6 col0" >7505219</td>
#       <td id="T_e93cc_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e93cc_row7_col0" class="data row7 col0" >1632262</td>
#       <td id="T_e93cc_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e93cc_row8_col0" class="data row8 col0" >1228037</td>
#       <td id="T_e93cc_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e93cc_row9_col0" class="data row9 col0" >7617513</td>
#       <td id="T_e93cc_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e93cc_row10_col0" class="data row10 col0" >7600841</td>
#       <td id="T_e93cc_row10_col1" class="data row10 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e93cc_row11_col0" class="data row11 col0" >7598014</td>
#       <td id="T_e93cc_row11_col1" class="data row11 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e93cc_row12_col0" class="data row12 col0" >7596109</td>
#       <td id="T_e93cc_row12_col1" class="data row12 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e93cc_row13_col0" class="data row13 col0" >7594452</td>
#       <td id="T_e93cc_row13_col1" class="data row13 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e93cc_row14_col0" class="data row14 col0" >7579947</td>
#       <td id="T_e93cc_row14_col1" class="data row14 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e93cc_row15_col0" class="data row15 col0" >7565353</td>
#       <td id="T_e93cc_row15_col1" class="data row15 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e93cc_row16_col0" class="data row16 col0" >7557967</td>
#       <td id="T_e93cc_row16_col1" class="data row16 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e93cc_row17_col0" class="data row17 col0" >7555585</td>
#       <td id="T_e93cc_row17_col1" class="data row17 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e93cc_row18_col0" class="data row18 col0" >7546942</td>
#       <td id="T_e93cc_row18_col1" class="data row18 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e93cc_row19_col0" class="data row19 col0" >7488418</td>
#       <td id="T_e93cc_row19_col1" class="data row19 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e93cc_row20_col0" class="data row20 col0" >7483390</td>
#       <td id="T_e93cc_row20_col1" class="data row20 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e93cc_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e93cc_row21_col0" class="data row21 col0" >7174141</td>
#       <

# %% [markdown]
# ## Beneficiários dos dois clientes com mais beneficiários

# %%
query = """SELECT TEST.BENEFICIARIO_ID FROM (
                SELECT CLIENTE_ID, COUNT (DISTINCT BENEFICIARIO_ID) AS QTD_BENEF FROM (
                    SELECT B.CLIENTE_ID, C.BENEFICIARIO_ID 
                    FROM ITEMCONTRATADO A
                    LEFT JOIN INSCRICAO B ON A.INSCRICAO_ID = B.ID
                    LEFT JOIN ITEMBENECIARIO C ON A.ID = C.ITEMCONTRATADO_ID)
                GROUP BY CLIENTE_ID
                ORDER BY COUNT(BENEFICIARIO_ID) DESC
                LIMIT 2) TESTE
                INNER JOIN (SELECT DISTINCT B.CLIENTE_ID, C.BENEFICIARIO_ID 
                    FROM ITEMCONTRATADO A
                    LEFT JOIN INSCRICAO B ON A.INSCRICAO_ID = B.ID
                    LEFT JOIN ITEMBENECIARIO C ON A.ID = C.ITEMCONTRATADO_ID) TEST ON TESTE.CLIENTE_ID = TEST.CLIENTE_ID"""
pd.read_sql(query, engine)
# Out:
#     BENEFICIARIO_ID
# 0         3631309.0
# 1         3631310.0
# 2         3631311.0
# 3         3631312.0
# 4         3631313.0
# 5         3631314.0
# 6         3623815.0
# 7         3623816.0
# 8         3623817.0
# 9         3623818.0
# 10        3623819.0
# 11        3780400.0

# %% [markdown]
# ## Classificação

# %%
query = """SELECT ID, CASE WHEN QUARTILE = 1 THEN "BAIXO"
                           WHEN QUARTILE = 2 THEN "MEDIO"
                           ELSE "ALTO" END AS CLASSIFICACAO
           FROM (SELECT *, NTILE(3) OVER(ORDER BY BENEFICIO_INICIAL DESC) AS Quartile 
                 FROM ITEMCONTRATADO)"""

pd.read_sql(query, engine)
# Out:
#            id CLASSIFICACAO
# 0    95865268         BAIXO
# 1    95865268         BAIXO
# 2    95865268         BAIXO
# 3    95865268         BAIXO
# 4    95665996         BAIXO
# ..        ...           ...
# 995  95733163          ALTO
# 996  95826958          ALTO
# 997  95963417          ALTO
# 998  95137127          ALTO
# 999  95864868          ALTO
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## ESTATÍSTICAS POR CLIENTE

# %%
query = """SELECT C.CLIENTE_ID, AVG(C.BENEFICIO_INICIAL) AS MEDIA, 
                  MIN(C.BENEFICIO_INICIAL) AS MIN,
                  MAX(C.BENEFICIO_INICIAL) AS MAX
                  FROM (SELECT B.CLIENTE_ID, A.BENEFICIO_INICIAL FROM ITEMCONTRATADO A 
                          LEFT JOIN INSCRICAO B ON A.INSCRICAO_ID = B.ID) C
            GROUP BY C.CLIENTE_ID"""

pd.read_sql(query, engine)
# Out:
#      CLIENTE_ID       MEDIA         MIN         MAX
# 0        144775   400000.00   400000.00   400000.00
# 1        168499    20000.00    20000.00    20000.00
# 2        206183   500000.00   500000.00   500000.00
# 3        208669    52885.48    52885.48    52885.48
# 4        235463   300000.00   300000.00   300000.00
# ..          ...         ...         ...         ...
# 630     7620078   450000.00   450000.00   450000.00
# 631     7620378  3000000.00  3000000.00  3000000.00
# 632     7621256   400000.00   400000.00   400000.00
# 633     7621715   500000.00   500000.00   500000.00
# 634     7621718   500000.00   500000.00   500000.00
#
# [635 rows x 4 columns]

# %% [markdown]
# ## Filtro de clientes

# %%
query = """SELECT DISTINCT C.* 
           FROM ITEMCONTRATADO A 
           LEFT JOIN INSCRICAO B ON A.INSCRICAO_ID = B.ID
           LEFT JOIN CLIENTE C ON B.CLIENTE_ID = C.ID
           WHERE B.PERIODICIDADE = "MENSAL" AND DATA_ASSINATURA >= '2022-01-06' AND DATA_ASSINATURA <= '2022-01-10'
           """

pd.read_sql(query, engine)
# Out:
#           id data_nascimento sexo
# 0    1750926      1977-10-06    M
# 1    4300961      1957-04-15    M
# 2    7488418      1963-03-05    F
# 3    2700079      1966-05-20    F
# 4    7503154      1983-03-04    F
# ..       ...             ...  ...
# 105  7598207      1988-12-09    F
# 106  7598014      1970-10-06    M
# 107  7598746      1990-03-29    M
# 108  2435127      1977-06-17    M
# 109  7599427      1991-05-31    F
#
# [110 rows x 3 columns]
